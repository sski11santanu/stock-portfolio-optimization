# %% [markdown]
# # Attempt 1
# ### Straight-forward using the existing sheet renamed to "T0 vs T1 Prices.csv"

# %%
import pandas as pd
from pulp import LpMaximize, LpProblem, LpVariable, lpSum

# %%
df = pd.read_csv("T0 vs T1 Prices.csv")
df.head()
# Out:
#            join_key          Name  Current Price  Units  Allocated_Budget  \
# 0   504084.0___NA__  Kaycee Inds.       63077.40    1.0           63077.4
# 1  523395.0_3MINDIA      3M India       37300.00    0.0               0.0
# 2   500068.0___NA__    Disa India       15731.30    0.0               0.0
# 3    505412.0_WENDT   Wendt India       15586.75    0.0               0.0
# 4   509152.0_GRPLTD           GRP       15007.65    0.0               0.0
#
#    t_1_price  Proft/Loss     Diff  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0   69368.56     6291.16  6291.16         NaN         NaN         NaN
# 1   41655.06        0.00  4355.06         NaN         NaN         NaN
# 2   17431.69        0.00  1700.39         NaN         NaN         NaN
# 3   16910.89        0.00  1324.14         NaN         NaN         NaN
# 4   16027.45        0.00  1019.80         NaN         NaN         NaN

# %%
df.tail()
# Out:
#             join_key             Name  Current Price  Units  Allocated_Budget  \
# 622  512591.0___NA__     Pulsar Intl.          14.04   10.0            140.40
# 623      -1.0_AAKASH   Aakash Explor.          14.16   12.0            169.92
# 624  511185.0___NA__  Rajvi Logitrade          11.29    0.0              0.00
# 625              NaN              NaN            NaN    NaN         954759.72
# 626              NaN              NaN            NaN    NaN               NaN
#
#      t_1_price  Proft/Loss  Diff  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 622      14.00       -0.40 -0.04         NaN         NaN          NaN
# 623      13.30      -10.32 -0.86         NaN         NaN          NaN
# 624      10.63     -123.42 -0.66         NaN         NaN          NaN
# 625        NaN    62494.46   NaN         NaN         NaN  6.545569392
# 626        NaN         NaN   NaN         NaN        10.0          NaN

# %%
df = df.loc[: 624, ["Name", "Current Price", "t_1_price"]]
# df.tail()

# %%
df.columns = ["Name", "t0", "t1"]

# %%
df["p10"] = df["t1"] - df["t0"]
df.tail()
# Out:
#                  Name     t0     t1   p10
# 620  RattanIndia Pow.  17.80  18.85  1.05
# 621    Shahi Shipping  17.12  15.62 -1.50
# 622      Pulsar Intl.  14.04  14.00 -0.04
# 623    Aakash Explor.  14.16  13.30 -0.86
# 624   Rajvi Logitrade  11.29  10.63 -0.66

# %%
t0 = df['t0'].values
t1 = df['t1'].values
p = df["p10"].values

# %%
n_companies = len(df)

# Define the problem
prob = LpProblem("Maximize_Profit", LpMaximize)
# Define decision variables
shares = [LpVariable(f"shares_{i}", lowBound = 0, cat = 'Integer') for i in range(n_companies)]
# Objective function
prob += lpSum([p[i] * shares[i] for i in range(n_companies)]), "Total_Profit"
# Constraint: Total investment should be less than or equal to 10 lakhs
prob += lpSum([t0[i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment"
# Solve the problem
prob.solve()

# Print the results
print("Optimal number of shares to buy for each company:")
total_cost = 0
total_profit = 0
shares_allocation = []
for i in range(n_companies):
    shares_allocation.append(int(shares[i].varValue))
    if shares[i].varValue > 0:
        print(f"Company {df['Name'][i]}: {shares[i].varValue} shares")
        total_cost += t0[i] * shares[i].varValue
        total_profit += p[i] * shares[i].varValue

# total_profit = sum([p[i] * shares[i].varValue for i in range(n_companies)])
print(f"Total Cost: {total_cost:.2f}")
print(f"Total Profit: {total_profit:.2f}")

df["allocation"] = shares_allocation
df.head()
# Out:
# Optimal number of shares to buy for each company:
# Company Bondada Engineer: 377.0 shares
# Company Premier Road: 44.0 shares
# Total Cost: 999986.20
# Total Profit: 222106.71
#            Name        t0        t1      p10  allocation
# 0  Kaycee Inds.  63077.40  69368.56  6291.16           0
# 1      3M India  37300.00  41655.06  4355.06           0
# 2    Disa India  15731.30  17431.69  1700.39           0
# 3   Wendt India  15586.75  16910.89  1324.14           0
# 4           GRP  15007.65  16027.45  1019.80           0

# %%
df.to_csv("ATTEMPT 1.csv", index = False)

# %% [markdown]
# # Attempt 2
# ### Using regression to predict T2 prices and linear programming to maximize profits p20

# %% [markdown]
# ## Data Processing

# %%
# Balance Sheet
df = pd.read_csv("Balance_Sheet_final.csv")
df = df[["Name", "join_key", "Market Capitalization", "Current Price"]]
balance_sheet_df = df[df["Name"] != "Divine Power"]
print(len(balance_sheet_df))
balance_sheet_df.head()
# Out:
# 4667
#                Name             join_key  Market Capitalization  Current Price
# 0        20 Microns   533022.0_20MICRONS                 795.54         225.45
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM                  73.96          70.44
# 2           360 ONE      542772.0_360ONE               36254.08         999.10
# 3       3B Blackbio      532067.0___NA__                1024.98        1194.20
# 4   3C IT Solutions      544190.0___NA__                  26.55          44.10

# %%
# T1 Prices
df = pd.read_csv("t1_prices.csv")
t1_df = df[df["join_key"] != "-1.0___NA__"]
print(len(t1_df))
t1_df.head()
# Out:
# 4667
#               join_key  t_1_price
# 0   533022.0_20MICRONS     229.42
# 1  526921.0_21STCENMGM      72.33
# 2      542772.0_360ONE    1025.83
# 3      532067.0___NA__    1329.94
# 4      544190.0___NA__      45.14

# %%
# Ratios 1
df = pd.read_csv("ratios_1_final.csv")
df = df[["join_key", "Piotroski score", "G Factor"]]
ratios1_df = df[df["join_key"] != "-1.0___NA__"]
print(len(ratios1_df))
ratios1_df.head()
# Out:
# 4667
#               join_key  Piotroski score  G Factor
# 0   533022.0_20MICRONS              8.0       6.0
# 1  526921.0_21STCENMGM              6.0       5.0
# 2      542772.0_360ONE              3.0       6.0
# 3      532067.0___NA__              5.0       3.0
# 4      544190.0___NA__              3.0       2.0

# %%
# Ratios 2
df = pd.read_csv("ratios_2_final.csv")
df = df[["join_key", "Average return on capital employed 3Years", "Average return on capital employed 5Years", "Average return on capital employed 7Years", "Average return on capital employed 10Years", "Average debtor days 3years", "Average Working Capital Days 3years"]]
ratios2_df = df[df["join_key"] != "-1.0___NA__"]
print(len(ratios2_df))
ratios2_df.head()
# Out:
# 4667
#               join_key  Average return on capital employed 3Years  \
# 0   533022.0_20MICRONS                                      20.14
# 1  526921.0_21STCENMGM                                      -1.17
# 2      542772.0_360ONE                                      13.73
# 3      532067.0___NA__                                      22.23
# 4      544190.0___NA__                                      27.48
#
#    Average return on capital employed 5Years  \
# 0                                      18.86
# 1                                      -6.00
# 2                                      11.58
# 3                                      51.94
# 4                                      27.48
#
#    Average return on capital employed 7Years  \
# 0                                      19.18
# 1                                      -0.97
# 2                                      11.46
# 3                                      44.46
# 4                                      27.48
#
#    Average return on capital employed 10Years  Average debtor days 3years  \
# 0                                       17.75                       56.42
# 1                                        4.67                       89.26
# 2                                       11.46                       47.33
# 3                                       33.72                      171.51
# 4                                       27.48                       66.12
#
#    Average Working Capital Days 3years
# 0                                84.01
# 1                                51.05
# 2                              -109.10
# 3                               210.92
# 4                                64.30

# %%
# Price
df = pd.read_csv("price_final.csv")
df = df[["join_key", "Volume 1month average", "Volume 1week average", "Volume", "Volume 1year average"]]
price_df = df[df["join_key"] != "-1.0___NA__"]
print(len(price_df))
price_df.head()
# Out:
# 4667
#               join_key  Volume 1month average  Volume 1week average   Volume  \
# 0   533022.0_20MICRONS                 729846                816052   312746
# 1  526921.0_21STCENMGM                  34120                 27069    11745
# 2      542772.0_360ONE                1193124               2871837  5329590
# 3      532067.0___NA__                  21265                  5355     7221
# 4      544190.0___NA__                 159500                 81000    74000
#
#    Volume 1year average
# 0                203559
# 1                 13416
# 2                705325
# 3                 13985
# 4                159500

# %%
# Other Metrics
df = pd.read_csv("other_metrics_final.csv")
df = df[["join_key", "ROCE3yr avg"]]
other_metrics_df = df[df["join_key"] != "-1.0___NA__"]
print(len(other_metrics_df))
other_metrics_df.head()
# Out:
# 4667
#               join_key  ROCE3yr avg
# 0   533022.0_20MICRONS        20.14
# 1  526921.0_21STCENMGM        -1.17
# 2      542772.0_360ONE        13.73
# 3      532067.0___NA__        22.23
# 4      544190.0___NA__        27.48

# %%
# Final df for attempt 2
df = balance_sheet_df
other_dfs = [t1_df, ratios1_df, ratios2_df, price_df, other_metrics_df]
for df2 in other_dfs:
    df = pd.merge(df, df2, on = "join_key", how = "inner")
print(len(df))
df.head()
# Out:
# 4667
#                Name             join_key  Market Capitalization  \
# 0        20 Microns   533022.0_20MICRONS                 795.54
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM                  73.96
# 2           360 ONE      542772.0_360ONE               36254.08
# 3       3B Blackbio      532067.0___NA__                1024.98
# 4   3C IT Solutions      544190.0___NA__                  26.55
#
#    Current Price  t_1_price  Piotroski score  G Factor  \
# 0         225.45     229.42              8.0       6.0
# 1          70.44      72.33              6.0       5.0
# 2         999.10    1025.83              3.0       6.0
# 3        1194.20    1329.94              5.0       3.0
# 4          44.10      45.14              3.0       2.0
#
#    Average return on capital employed 3Years  \
# 0                                      20.14
# 1                                      -1.17
# 2                                      13.73
# 3                                      22.23
# 4                                      27.48
#
#    Average return on capital employed 5Years  \
# 0                                      18.86
# 1                                      -6.00
# 2                                      11.58
# 3                                      51.94
# 4                                      27.48
#
#    Average return on capital employed 7Years  \
# 0                                      19.18
# 1                                      -0.97
# 2                                      11.46
# 3                                      44.46
# 4                                      27.48
#
#    Average return on capital employed 10Years  Average debtor days 3years  \
# 0                                       17.75                       56.42
# 1                                        4.67                       89.26
# 2                                       11.46                       47.33
# 3                                       33.72                      171.51
# 4                                       27.48                       66.12
#
#    Average Working Capital Days 3years  Volume 1month average  \
# 0                                84.01                 729846
# 1                                51.05                  34120
# 2                              -109.10                1193124
# 3                               210.92                  21265
# 4                                64.30                 159500
#
#    Volume 1week average   Volume  Volume 1year average  ROCE3yr avg
# 0                816052   312746                203559        20.14
# 1                 27069    11745                 13416        -1.17
# 2               2871837  5329590                705325        13.73
# 3                  5355     7221                 13985        22.23
# 4                 81000    74000                159500        27.48

# %%
df.to_csv("attempt 2 df.csv", index = False)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
y = df["t_1_price"]
X = df.drop(["Name", "join_key", "t_1_price"], axis = 1)
print(X.shape, y.shape)
# Out:
# (4667, 15) (4667,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (3266, 15) (1401, 15)
# (3266,) (1401,)

# %% [markdown]
# ## Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
# y = df["t_1_price"]
# X = df.drop(["Name", "join_key", "t_1_price"], axis = 1)
# print(X.shape, y.shape)
# Out:
# (4667, 15) (4667,)

# %%
models = [LinearRegression(), Ridge(alpha = 0.1), DecisionTreeRegressor(random_state = 0), RandomForestRegressor(random_state = 0)]
best_model = None
best_r2 = None
best_i = 0
for i, model in enumerate(models, 1):
    model.fit(X_train, y_train)
    yhat = model.predict(X_test)
    mse = mean_squared_error(y_test, yhat)
    r2 = r2_score(y_test, yhat)
    print(f"MODEL - {i}:")
    print(f"MSE = {mse}")
    print(f"R2 Score = {r2}")
    print()

    if not best_model or r2 > best_r2:
        best_model = model
        best_r2 = r2
        best_i = i
print(f"Best model = Model - {best_i}")
# Out:
# MODEL - 1:
# MSE = 30571.49537409865
# R2 Score = 0.9971039469453501
#
# MODEL - 2:
# MSE = 30571.49529671456
# R2 Score = 0.9971039469526808
#
# MODEL - 3:
# MSE = 2916087.8064882937
# R2 Score = 0.7237575428919731
# c:\Users\iitsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.40957e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# MODEL - 4:
# MSE = 211797.345099339
# R2 Score = 0.9799363315161432
#
# Best model = Model - 2

# %% [markdown]
# ## Inference (Getting T2 Prices)

# %%
# Set T1 prices as the current price for predicting the T2 prices
t0 = X["Current Price"].values
t1 = y.values
X["Current Price"] = y
t2 = best_model.predict(X)

# %%
# type(t2)
# Out:
# numpy.ndarray

# %%
# Create the dataframe of the prices T0 to T2
t0t1t2_df = pd.DataFrame()
t0t1t2_df[["Name", "join_key"]] = df[["Name", "join_key"]]
t0t1t2_df["t0"] = t0
t0t1t2_df["t1"] = t1
t0t1t2_df["t2"] = t2
print(t0t1t2_df.shape)
t0t1t2_df.head()
# Out:
# (4667, 5)
#                Name             join_key       t0       t1           t2
# 0        20 Microns   533022.0_20MICRONS   225.45   229.42   260.447690
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    86.484221
# 2           360 ONE      542772.0_360ONE   999.10  1025.83  1068.317392
# 3       3B Blackbio      532067.0___NA__  1194.20  1329.94  1371.522189
# 4   3C IT Solutions      544190.0___NA__    44.10    45.14    34.605736

# %%
# t0t1t2_df[t0t1t2_df["t2"] != t0t1t2_df["t1"]]
# Out:
#                   Name             join_key       t0       t1       t2
# 0           20 Microns   533022.0_20MICRONS   225.45   229.42   229.42
# 1     21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    72.33
# 2              360 ONE      542772.0_360ONE   999.10  1025.83  1025.83
# 3          3B Blackbio      532067.0___NA__  1194.20  1329.94  1329.94
# 4      3C IT Solutions      544190.0___NA__    44.10    45.14    45.14
# ...                ...                  ...      ...      ...      ...
# 4662  Zota Health Care            -1.0_ZOTA   573.40   550.89   550.89
# 4663  Zuari Agro Chem.       534742.0_ZUARI   226.70   197.72   197.72
# 4664  Zuari Industries    500780.0_ZUARIIND   403.90   434.14   434.14
# 4665    Zydus Lifesci.   532321.0_ZYDUSLIFE  1069.30  1144.44  1144.44
# 4666    Zydus Wellness   531335.0_ZYDUSWELL  1856.60  1885.11  1885.11
#
# [4667 rows x 5 columns]

# %%
t0t1t2_df.to_csv("T0 vs T1 vs T2 Prices.csv", index = False)

# %% [markdown]
# ## Maximizing Profits

# %%
df = t0t1t2_df
df["p20"] = df["t2"] - df["t0"]
df["p21"] = df["t2"] - df["t1"]
df["p10"] = df["t1"] - df["t0"]
df.head()
# Out:
#                Name             join_key       t0       t1           t2  \
# 0        20 Microns   533022.0_20MICRONS   225.45   229.42   260.447690
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    86.484221
# 2           360 ONE      542772.0_360ONE   999.10  1025.83  1068.317392
# 3       3B Blackbio      532067.0___NA__  1194.20  1329.94  1371.522189
# 4   3C IT Solutions      544190.0___NA__    44.10    45.14    34.605736
#
#           p20        p21     p10
# 0   34.997690  31.027690    3.97
# 1   16.044221  14.154221    1.89
# 2   69.217392  42.487392   26.73
# 3  177.322189  41.582189  135.74
# 4   -9.494264 -10.534264    1.04

# %%
# Get the best allocation based on an upper limit on the number of shares allocated per company/stock
n_companies = len(df)
upper_bounds = [100, 200, 500, 1000, 2000, 3000, 4000, 5000, 8000, 10000]
allocations = dict()
best_profit_10 = [None, None]
best_profit_21 = [None, None]
best_profit_20 = [None, None]
# best_profit_total = [None, None]

for ub in upper_bounds:
    # Define the problem
    prob = LpProblem("Maximize_Profit", LpMaximize)
    # Define decision variables
    shares = [LpVariable(f"shares_{i}", lowBound = 0, upBound = ub, cat = 'Integer') for i in range(n_companies)]
    # Objective function
    prob += lpSum([df["p20"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T20"
    # prob += lpSum([df["p21"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T21"
    # prob += lpSum([df["p10"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T10"
    # Constraint: Total investment should be less than or equal to 10 lakhs
    # prob += lpSum([df["t1"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T1"
    prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T0_Max"
    # prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) >= 900000, "Total_Investment_T0_Min"
    # Solve the problem
    prob.solve()

    # Print the results
    print("Optimal number of shares to buy for each company:")
    total_cost_10 = 0
    total_profit_10 = 0
    total_cost_21 = 0
    total_profit_21 = 0
    total_profit_20 = 0
    shares_allocation = []
    for i in range(n_companies):
        shares_allocation.append(int(shares[i].varValue))
        if shares[i].varValue > 0:
            # print(f"Company {df['Name'][i]}: {shares[i].varValue} shares")
            total_cost_10 += df["t0"][i] * shares[i].varValue
            total_profit_10 += df["p10"][i] * shares[i].varValue
            total_cost_21 += df["t1"][i] * shares[i].varValue
            total_profit_21 += df["p21"][i] * shares[i].varValue
            total_profit_20 += df["p20"][i] * shares[i].varValue

    # total_profit = sum([p[i] * shares[i].varValue for i in range(n_companies)])
    # total_profit = total_profit_10 + total_profit_21
    allocations[ub] = shares_allocation
    print("Upper Bound on each allocation (number of shares): ", ub)
    print(f"Total Cost at T0: {total_cost_10:.2f}")
    print(f"Total Profit from T0 to T1: {total_profit_10:.2f}")
    # print()
    print(f"Total Cost at T1: {total_cost_21:.2f}")
    print(f"Total Profit from T1 to T2: {total_profit_21:.2f}")
    print(f"Total Profit from T0 to T2 (Overall): {total_profit_20:.2f}")
    print()

    if best_profit_10[0] is None or total_profit_10 > best_profit_10[1]:
        best_profit_10[0] = ub
        best_profit_10[1] = total_profit_10
    if best_profit_21[0] is None or total_profit_21 > best_profit_21[1]:
        best_profit_21[0] = ub
        best_profit_21[1] = total_profit_21
    if best_profit_20[0] is None or total_profit_20 > best_profit_20[1]:
        best_profit_20[0] = ub
        best_profit_20[1] = total_profit_20

print(f"Best Profit (T1 - T0): {best_profit_10}")
print(f"Best Profit (T2 - T1): {best_profit_21}")
print(f"Best Overall Profit (T2 - T0): {best_profit_20}")
# Out:
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  100
# Total Cost at T0: 999999.83
# Total Profit from T0 to T1: -824.46
# Total Cost at T1: 999175.37
# Total Profit from T1 to T2: 677266.96
# Total Profit from T0 to T2 (Overall): 676442.50
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  200
# Total Cost at T0: 999999.98
# Total Profit from T0 to T1: -9269.65
# Total Cost at T1: 990730.33
# Total Profit from T1 to T2: 968725.41
# Total Profit from T0 to T2 (Overall): 959455.76
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  500
# Total Cost at T0: 999999.95
# Total Profit from T0 to T1: -19503.31
# Total Cost at T1: 980496.64
# Total Profit from T1 to T2: 1499741.99
# Total Profit from T0 to T2 (Overall): 1480238.68
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  1000
# Total Cost at T0: 1000000.00
# Total Profit from T0 to T1: -21016.90
# Total Cost at T1: 978983.10
# Total Profit from T1 to T2: 2059136.04
# Total Profit from T0 to T2 (Overall): 2038119.14
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  2000
# Total Cost at T0: 1000000.00
# Total Profit from T0 to T1: -27630.44
# Total Cost at T1: 972369.56
# Total Profit from T1 to T2: 2826971.50
# Total Profit from T0 to T2 (Overall): 2799341.06
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  3000
# Total Cost at T0: 999999.96
# Total Profit from T0 to T1: -28665.68
# Total Cost at T1: 971334.28
# Total Profit from T1 to T2: 3436246.16
# Total Profit from T0 to T2 (Overall): 3407580.48
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  4000
# Total Cost at T0: 999999.83
# Total Profit from T0 to T1: -30045.46
# Total Cost at T1: 969954.37
# Total Profit from T1 to T2: 3966074.28
# Total Profit from T0 to T2 (Overall): 3936028.82
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  5000
# Total Cost at T0: 999999.99
# Total Profit from T0 to T1: -35425.21
# Total Cost at T1: 964574.78
# Total Profit from T1 to T2: 4385217.35
# Total Profit from T0 to T2 (Overall): 4349792.14
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  8000
# Total Cost at T0: 999999.90
# Total Profit from T0 to T1: -23411.47
# Total Cost at T1: 976588.43
# Total Profit from T1 to T2: 5385099.55
# Total Profit from T0 to T2 (Overall): 5361688.08
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  10000
# Total Cost at T0: 999999.95
# Total Profit from T0 to T1: -16907.83
# Total Cost at T1: 983092.12
# Total Profit from T1 to T2: 5879953.03
# Total Profit from T0 to T2 (Overall): 5863045.20
#
# Best Profit (T1 - T0): [100, -824.4599999999956]
# Best Profit (T2 - T1): [10000, 5879953.031288757]
# Best Overall Profit (T2 - T0): [10000, 5863045.201288757]

# %%
df[(df["p20"] >= 0) & (df["p10"] <= 0)]
# Out:
#                   Name           join_key       t0       t1           t2  \
# 7        3P Land Hold.    516092.0_3PLAND    38.18    36.98    46.057839
# 8      52 Weeks Enter.    531925.0___NA__     1.69     1.55     2.434830
# 14      A B Infrabuild       -1.0_ABINFRA    55.00    54.76    60.678745
# 16     A F Enterprises    538351.0___NA__    11.30    11.03    11.664065
# 21    A.K.Capital Serv    530499.0___NA__  1050.00  1017.94  1060.896717
# ...                ...                ...      ...      ...          ...
# 4635  Yuranus Infrast.    536846.0___NA__   127.00   123.88   140.183795
# 4636   Yuvraaj Hygiene    531663.0___NA__     1.78     1.77     7.189048
# 4643         Zee Learn  533287.0_ZEELEARN     7.74     7.25    32.069971
# 4648     Zenith Fibres    514266.0___NA__    85.00    83.34    92.967500
# 4649     Zenith Health    530665.0___NA__     4.26     4.02    13.836300
#
#             p20        p21    p10
# 7      7.877839   9.077839  -1.20
# 8      0.744830   0.884830  -0.14
# 14     5.678745   5.918745  -0.24
# 16     0.364065   0.634065  -0.27
# 21    10.896717  42.956717 -32.06
# ...         ...        ...    ...
# 4635  13.183795  16.303795  -3.12
# 4636   5.409048   5.419048  -0.01
# 4643  24.329971  24.819971  -0.49
# 4648   7.967500   9.627500  -1.66
# 4649   9.576300   9.816300  -0.24
#
# [1186 rows x 8 columns]

# %%
df["allocation"] = allocations[10000]
df.head()
# Out:
#                Name             join_key       t0       t1           t2  \
# 0        20 Microns   533022.0_20MICRONS   225.45   229.42   260.447690
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    86.484221
# 2           360 ONE      542772.0_360ONE   999.10  1025.83  1068.317392
# 3       3B Blackbio      532067.0___NA__  1194.20  1329.94  1371.522189
# 4   3C IT Solutions      544190.0___NA__    44.10    45.14    34.605736
#
#           p20        p21     p10  allocation
# 0   34.997690  31.027690    3.97           0
# 1   16.044221  14.154221    1.89           0
# 2   69.217392  42.487392   26.73           0
# 3  177.322189  41.582189  135.74           0
# 4   -9.494264 -10.534264    1.04           0

# %%
sum(df["allocation"] > 0)
# Out:
# 46

# %%
df.to_csv("ATTEMPT 2.csv", index = False)

# %% [markdown]
# # Attempt 3
# ### Maximizing profits p20 (the actual desired profits) as well as p10

# %%
# Get the best allocation based on an upper limit on the number of shares allocated per company/stock
n_companies = len(df)
upper_bounds = [100, 200, 500, 1000, 2000, 3000, 4000, 5000, 8000, 10000]
allocations = dict()
best_profit_10 = [None, None]
best_profit_21 = [None, None]
best_profit_20 = [None, None]
# best_profit_total = [None, None]

for ub in upper_bounds:
    # Define the problem
    prob = LpProblem("Maximize_Profit", LpMaximize)
    # Define decision variables
    shares = [LpVariable(f"shares_{i}", lowBound = 0, upBound = ub, cat = 'Integer') for i in range(n_companies)]
    # Objective function
    prob += lpSum([df["p20"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T20"
    # prob += lpSum([df["p21"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T21"
    prob += lpSum([df["p10"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T10"
    # Constraint: Total investment should be less than or equal to 10 lakhs
    # prob += lpSum([df["t1"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T1"
    prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T0_Max"
    # prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) >= 900000, "Total_Investment_T0_Min"
    # Solve the problem
    prob.solve()

    # Print the results
    print("Optimal number of shares to buy for each company:")
    total_cost_10 = 0
    total_profit_10 = 0
    total_cost_21 = 0
    total_profit_21 = 0
    total_profit_20 = 0
    shares_allocation = []
    for i in range(n_companies):
        shares_allocation.append(int(shares[i].varValue))
        if shares[i].varValue > 0:
            # print(f"Company {df['Name'][i]}: {shares[i].varValue} shares")
            total_cost_10 += df["t0"][i] * shares[i].varValue
            total_profit_10 += df["p10"][i] * shares[i].varValue
            total_cost_21 += df["t1"][i] * shares[i].varValue
            total_profit_21 += df["p21"][i] * shares[i].varValue
            total_profit_20 += df["p20"][i] * shares[i].varValue

    # total_profit = sum([p[i] * shares[i].varValue for i in range(n_companies)])
    # total_profit = total_profit_10 + total_profit_21
    allocations[ub] = shares_allocation
    print("Upper Bound on each allocation (number of shares): ", ub)
    print(f"Total Cost at T0: {total_cost_10:.2f}")
    print(f"Total Profit from T0 to T1: {total_profit_10:.2f}")
    # print()
    print(f"Total Cost at T1: {total_cost_21:.2f}")
    print(f"Total Profit from T1 to T2: {total_profit_21:.2f}")
    print(f"Total Profit from T0 to T2 (Overall): {total_profit_20:.2f}")
    print()

    if best_profit_10[0] is None or total_profit_10 > best_profit_10[1]:
        best_profit_10[0] = ub
        best_profit_10[1] = total_profit_10
    if best_profit_21[0] is None or total_profit_21 > best_profit_21[1]:
        best_profit_21[0] = ub
        best_profit_21[1] = total_profit_21
    if best_profit_20[0] is None or total_profit_20 > best_profit_20[1]:
        best_profit_20[0] = ub
        best_profit_20[1] = total_profit_20

print(f"Best Profit (T1 - T0): {best_profit_10}")
print(f"Best Profit (T2 - T1): {best_profit_21}")
print(f"Best Overall Profit (T2 - T0): {best_profit_20}")
# Out:
# c:\Users\iitsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pulp\pulp.py:1704: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  100
# Total Cost at T0: 999999.98
# Total Profit from T0 to T1: 254856.08
# Total Cost at T1: 1254856.06
# Total Profit from T1 to T2: 43951.82
# Total Profit from T0 to T2 (Overall): 298807.90
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  200
# Total Cost at T0: 999999.94
# Total Profit from T0 to T1: 270577.30
# Total Cost at T1: 1270577.24
# Total Profit from T1 to T2: 43454.71
# Total Profit from T0 to T2 (Overall): 314032.01
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  500
# Total Cost at T0: 999999.94
# Total Profit from T0 to T1: 270619.62
# Total Cost at T1: 1270619.56
# Total Profit from T1 to T2: 48079.37
# Total Profit from T0 to T2 (Overall): 318698.99
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  1000
# Total Cost at T0: 999999.97
# Total Profit from T0 to T1: 270661.83
# Total Cost at T1: 1270661.80
# Total Profit from T1 to T2: 52705.39
# Total Profit from T0 to T2 (Overall): 323367.22
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  2000
# Total Cost at T0: 999999.89
# Total Profit from T0 to T1: 270769.35
# Total Cost at T1: 1270769.24
# Total Profit from T1 to T2: 64263.28
# Total Profit from T0 to T2 (Overall): 335032.63
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  3000
# Total Cost at T0: 999999.56
# Total Profit from T0 to T1: 270899.65
# Total Cost at T1: 1270899.21
# Total Profit from T1 to T2: 78184.40
# Total Profit from T0 to T2 (Overall): 349084.05
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  4000
# Total Cost at T0: 999999.99
# Total Profit from T0 to T1: 271003.74
# Total Cost at T1: 1271003.73
# Total Profit from T1 to T2: 89730.12
# Total Profit from T0 to T2 (Overall): 360733.86
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  5000
# Total Cost at T0: 999999.96
# Total Profit from T0 to T1: 271111.19
# Total Cost at T1: 1271111.15
# Total Profit from T1 to T2: 101306.98
# Total Profit from T0 to T2 (Overall): 372418.17
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  8000
# Total Cost at T0: 999999.76
# Total Profit from T0 to T1: 271433.51
# Total Cost at T1: 1271433.27
# Total Profit from T1 to T2: 136111.18
# Total Profit from T0 to T2 (Overall): 407544.69
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  10000
# Total Cost at T0: 999999.95
# Total Profit from T0 to T1: 271667.90
# Total Cost at T1: 1271667.85
# Total Profit from T1 to T2: 161530.76
# Total Profit from T0 to T2 (Overall): 433198.66
#
# Best Profit (T1 - T0): [10000, 271667.89999999997]
# Best Profit (T2 - T1): [10000, 161530.76011314293]
# Best Overall Profit (T2 - T0): [10000, 433198.6601131429]

# %%
df["allocation"] = allocations[10000]
df.head()
# Out:
#                Name             join_key       t0       t1           t2  \
# 0        20 Microns   533022.0_20MICRONS   225.45   229.42   260.447690
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    86.484221
# 2           360 ONE      542772.0_360ONE   999.10  1025.83  1068.317392
# 3       3B Blackbio      532067.0___NA__  1194.20  1329.94  1371.522189
# 4   3C IT Solutions      544190.0___NA__    44.10    45.14    34.605736
#
#           p20        p21     p10  allocation
# 0   34.997690  31.027690    3.97           0
# 1   16.044221  14.154221    1.89           0
# 2   69.217392  42.487392   26.73           0
# 3  177.322189  41.582189  135.74           0
# 4   -9.494264 -10.534264    1.04           0

# %%
sum(df["allocation"] > 0)
# Out:
# 5

# %%
df.to_csv("ATTEMPT 3.csv", index = False)

# %% [markdown]
# # Attempt 4
# ### Choose smaller upper bound on stock allocations for lower risk

# %%
df["allocation"] = allocations[500]
df.head()
# Out:
#                Name             join_key       t0       t1           t2  \
# 0        20 Microns   533022.0_20MICRONS   225.45   229.42   260.447690
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM    70.44    72.33    86.484221
# 2           360 ONE      542772.0_360ONE   999.10  1025.83  1068.317392
# 3       3B Blackbio      532067.0___NA__  1194.20  1329.94  1371.522189
# 4   3C IT Solutions      544190.0___NA__    44.10    45.14    34.605736
#
#           p20        p21     p10  allocation
# 0   34.997690  31.027690    3.97           0
# 1   16.044221  14.154221    1.89           0
# 2   69.217392  42.487392   26.73           0
# 3  177.322189  41.582189  135.74           0
# 4   -9.494264 -10.534264    1.04           0

# %%
sum(df["allocation"] > 0)
# Out:
# 4

# %%
df.to_csv("ATTEMPT 4.csv", index = False)

# %% [markdown]
# # Attempt 5
# ### Employing the same algorithm from attempt 2 on the safe companies

# %% [markdown]
# ## Data Processing

# %%
df = pd.read_csv("attempt 2 df.csv")
df.head()
# Out:
#                Name             join_key  Market Capitalization  \
# 0        20 Microns   533022.0_20MICRONS                 795.54
# 1  21st Cent. Mgmt.  526921.0_21STCENMGM                  73.96
# 2           360 ONE      542772.0_360ONE               36254.08
# 3       3B Blackbio      532067.0___NA__                1024.98
# 4   3C IT Solutions      544190.0___NA__                  26.55
#
#    Current Price  t_1_price  Piotroski score  G Factor  \
# 0         225.45     229.42              8.0       6.0
# 1          70.44      72.33              6.0       5.0
# 2         999.10    1025.83              3.0       6.0
# 3        1194.20    1329.94              5.0       3.0
# 4          44.10      45.14              3.0       2.0
#
#    Average return on capital employed 3Years  \
# 0                                      20.14
# 1                                      -1.17
# 2                                      13.73
# 3                                      22.23
# 4                                      27.48
#
#    Average return on capital employed 5Years  \
# 0                                      18.86
# 1                                      -6.00
# 2                                      11.58
# 3                                      51.94
# 4                                      27.48
#
#    Average return on capital employed 7Years  \
# 0                                      19.18
# 1                                      -0.97
# 2                                      11.46
# 3                                      44.46
# 4                                      27.48
#
#    Average return on capital employed 10Years  Average debtor days 3years  \
# 0                                       17.75                       56.42
# 1                                        4.67                       89.26
# 2                                       11.46                       47.33
# 3                                       33.72                      171.51
# 4                                       27.48                       66.12
#
#    Average Working Capital Days 3years  Volume 1month average  \
# 0                                84.01                 729846
# 1                                51.05                  34120
# 2                              -109.10                1193124
# 3                               210.92                  21265
# 4                                64.30                 159500
#
#    Volume 1week average   Volume  Volume 1year average  ROCE3yr avg
# 0                816052   312746                203559        20.14
# 1                 27069    11745                 13416        -1.17
# 2               2871837  5329590                705325        13.73
# 3                  5355     7221                 13985        22.23
# 4                 81000    74000                159500        27.48

# %%
safe_companies = pd.read_csv("safe_companies.csv")
safe_companies = safe_companies[["Name", "Price to Sales_x", "EVEBITDA_x", "Working Capital to Sales ratio", "QoQ Profits", "QoQ Sales", "Net worth", "Market Cap to Sales", "Enterprise Value to EBIT", "Debt To Profit", "Total Capital Employed", "Leverage", "Dividend Payout", "Cash by market cap", "52w Index", "Down from 52w high", "Up from 52w low", "From 52w high", "Dividend Payout Ratio", "Market Capt to Cash Flow", "Altman Z Score_x"]]
safe_companies.head()
# Out:
#                Name  Price to Sales_x  EVEBITDA_x  \
# 0        20 Microns              1.02        7.80
# 1          3M India             10.71       52.94
# 2             A B B             16.24       84.24
# 3    Aakash Explor.              1.55        9.07
# 4  Aaron Industries              4.34       26.93
#
#    Working Capital to Sales ratio  QoQ Profits  QoQ Sales  Net worth  \
# 0                           31.86        18.78      21.41     352.95
# 1                           34.92        29.44       9.66    2370.20
# 2                           40.96        35.62      11.71    5944.60
# 3                           19.38       756.10      41.70      58.53
# 4                           27.44        94.17      30.51      35.84
#
#    Market Cap to Sales  Enterprise Value to EBIT  Debt To Profit  ...  \
# 0                 1.02                      8.97            2.16  ...
# 1                10.71                     56.74            0.03  ...
# 2                16.24                     89.56            0.04  ...
# 3                 1.55                     15.81            2.92  ...
# 4                 4.34                     30.81            4.99  ...
#
#    Leverage  Dividend Payout  Cash by market cap  52w Index  \
# 0      1.57             7.87                0.06      93.07
# 1      1.33           143.96                0.02      80.55
# 2      1.71            40.60                0.02      87.27
# 3      1.51             0.00                0.01      87.22
# 4      1.58            16.54                0.01      40.87
#
#    Down from 52w high  Up from 52w low  From 52w high  Dividend Payout Ratio  \
# 0                4.27           149.89           0.96                   7.87
# 1                6.46            40.08           0.94                 143.96
# 2                7.40           121.41           0.93                  40.60
# 3                8.05           148.42           0.92                   0.00
# 4               19.79            20.56           0.80                  16.54
#
#    Market Capt to Cash Flow  Altman Z Score_x
# 0                     14.58              5.36
# 1                     72.06             23.11
# 2                    133.57             29.11
# 3                     14.04              4.89
# 4                     48.96              8.11
#
# [5 rows x 21 columns]

# %%
df = pd.merge(df, safe_companies, on = "Name", how = "inner")
print(len(df))
df.head()
# Out:
# 366
#                Name            join_key  Market Capitalization  Current Price  \
# 0        20 Microns  533022.0_20MICRONS                 795.54         225.45
# 1          3M India    523395.0_3MINDIA               42048.39       37310.00
# 2             A B B        500002.0_ABB              180784.34        8531.25
# 3    Aakash Explor.         -1.0_AAKASH                 143.37          14.16
# 4  Aaron Industries          -1.0_AARON                 275.65         263.20
#
#    t_1_price  Piotroski score  G Factor  \
# 0     229.42              8.0       6.0
# 1   41655.06              9.0       4.0
# 2    9620.43              9.0       5.0
# 3      13.30              9.0       5.0
# 4     258.78              3.0       5.0
#
#    Average return on capital employed 3Years  \
# 0                                      20.14
# 1                                      24.53
# 2                                      23.27
# 3                                      13.31
# 4                                      24.11
#
#    Average return on capital employed 5Years  \
# 0                                      18.86
# 1                                      19.83
# 2                                      18.23
# 3                                      13.61
# 4                                      21.16
#
#    Average return on capital employed 7Years  ...  Leverage  Dividend Payout  \
# 0                                      19.18  ...      1.57             7.87
# 1                                      23.28  ...      1.33           143.96
# 2                                      17.55  ...      1.71            40.60
# 3                                      13.32  ...      1.51             0.00
# 4                                      24.69  ...      1.58            16.54
#
#    Cash by market cap  52w Index  Down from 52w high  Up from 52w low  \
# 0                0.06      93.07                4.27           149.89
# 1                0.02      80.55                6.46            40.08
# 2                0.02      87.27                7.40           121.41
# 3                0.01      87.22                8.05           148.42
# 4                0.01      40.87               19.79            20.56
#
#    From 52w high  Dividend Payout Ratio  Market Capt to Cash Flow  \
# 0           0.96                   7.87                     14.58
# 1           0.94                 143.96                     72.06
# 2           0.93                  40.60                    133.57
# 3           0.92                   0.00                     14.04
# 4           0.80                  16.54                     48.96
#
#    Altman Z Score_x
# 0              5.36
# 1             23.11
# 2             29.11
# 3              4.89
# 4              8.11
#
# [5 rows x 38 columns]

# %%
df.to_csv("attempt 5 df.csv", index = False)

# %% [markdown]
# ## Train Test Split

# %%
y = df["t_1_price"]
X = df.drop(["Name", "join_key", "t_1_price"], axis = 1)
print(X.shape, y.shape)
# Out:
# (366, 35) (366,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (256, 35) (110, 35)
# (256,) (110,)

# %% [markdown]
# ## Regression

# %%
models = [LinearRegression(), Ridge(alpha = 0.1), DecisionTreeRegressor(random_state = 0), RandomForestRegressor(random_state = 0)]
best_model = None
best_r2 = None
best_i = 0
for i, model in enumerate(models, 1):
    model.fit(X_train, y_train)
    yhat = model.predict(X_test)
    mse = mean_squared_error(y_test, yhat)
    r2 = r2_score(y_test, yhat)
    print(f"MODEL - {i}:")
    print(f"MSE = {mse}")
    print(f"R2 Score = {r2}")
    print()

    if not best_model or r2 > best_r2:
        best_model = model
        best_r2 = r2
        best_i = i
print(f"Best model = Model - {best_i}")
# Out:
# MODEL - 1:
# MSE = 27737.701590986337
# R2 Score = 0.9969966247208891
#
# MODEL - 2:
# MSE = 27577.17402525146
# R2 Score = 0.9970140062808198
#
# MODEL - 3:
# MSE = 16623517.821171816
# R2 Score = -0.7999567236021574
# c:\Users\iitsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.07599e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# MODEL - 4:
# MSE = 4592255.497287253
# R2 Score = 0.5027610131765428
#
# Best model = Model - 2

# %% [markdown]
# ## Inference

# %%
# Set T1 prices as the current price for predicting the T2 prices
t0 = X["Current Price"].values
t1 = y.values
X["Current Price"] = y
t2 = best_model.predict(X)

# %%
# Create the dataframe of the prices T0 to T2
t0t1t2_df = pd.DataFrame()
t0t1t2_df[["Name", "join_key"]] = df[["Name", "join_key"]]
t0t1t2_df["t0"] = t0
t0t1t2_df["t1"] = t1
t0t1t2_df["t2"] = t2
print(t0t1t2_df.shape)
t0t1t2_df.head()
# Out:
# (366, 5)
#                Name            join_key        t0        t1            t2
# 0        20 Microns  533022.0_20MICRONS    225.45    229.42    227.561919
# 1          3M India    523395.0_3MINDIA  37310.00  41655.06  45885.999153
# 2             A B B        500002.0_ABB   8531.25   9620.43  10533.824027
# 3    Aakash Explor.         -1.0_AAKASH     14.16     13.30    -58.956361
# 4  Aaron Industries          -1.0_AARON    263.20    258.78    295.829774

# %%
t0t1t2_df.to_csv("Safe Companies T0 vs T1 vs T2 Prices.csv", index = False)

# %% [markdown]
# ## Linear Programming

# %%
df = t0t1t2_df
df["p20"] = df["t2"] - df["t0"]
df["p21"] = df["t2"] - df["t1"]
df["p10"] = df["t1"] - df["t0"]
df.head()
# Out:
#                Name            join_key        t0        t1            t2  \
# 0        20 Microns  533022.0_20MICRONS    225.45    229.42    227.561919
# 1          3M India    523395.0_3MINDIA  37310.00  41655.06  45885.999153
# 2             A B B        500002.0_ABB   8531.25   9620.43  10533.824027
# 3    Aakash Explor.         -1.0_AAKASH     14.16     13.30    -58.956361
# 4  Aaron Industries          -1.0_AARON    263.20    258.78    295.829774
#
#            p20          p21      p10
# 0     2.111919    -1.858081     3.97
# 1  8575.999153  4230.939153  4345.06
# 2  2002.574027   913.394027  1089.18
# 3   -73.116361   -72.256361    -0.86
# 4    32.629774    37.049774    -4.42

# %%
# Get the best allocation based on an upper limit on the number of shares allocated per company/stock
n_companies = len(df)
upper_bounds = [100, 200, 500, 1000, 2000, 3000, 4000, 5000, 8000, 10000]
allocations = dict()
best_profit_10 = [None, None]
best_profit_21 = [None, None]
best_profit_20 = [None, None]
# best_profit_total = [None, None]

for ub in upper_bounds:
    # Define the problem
    prob = LpProblem("Maximize_Profit", LpMaximize)
    # Define decision variables
    shares = [LpVariable(f"shares_{i}", lowBound = 0, upBound = ub, cat = 'Integer') for i in range(n_companies)]
    # Objective function
    prob += lpSum([df["p20"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T20"
    # prob += lpSum([df["p21"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T21"
    # prob += lpSum([df["p10"][i] * shares[i] for i in range(n_companies)]), "Total_Profit_T10"
    # Constraint: Total investment should be less than or equal to 10 lakhs
    # prob += lpSum([df["t1"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T1"
    prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) <= 1000000, "Total_Investment_T0_Max"
    # prob += lpSum([df["t0"][i] * shares[i] for i in range(n_companies)]) >= 900000, "Total_Investment_T0_Min"
    # Solve the problem
    prob.solve()

    # Print the results
    print("Optimal number of shares to buy for each company:")
    total_cost_10 = 0
    total_profit_10 = 0
    total_cost_21 = 0
    total_profit_21 = 0
    total_profit_20 = 0
    shares_allocation = []
    for i in range(n_companies):
        shares_allocation.append(int(shares[i].varValue))
        if shares[i].varValue > 0:
            # print(f"Company {df['Name'][i]}: {shares[i].varValue} shares")
            total_cost_10 += df["t0"][i] * shares[i].varValue
            total_profit_10 += df["p10"][i] * shares[i].varValue
            total_cost_21 += df["t1"][i] * shares[i].varValue
            total_profit_21 += df["p21"][i] * shares[i].varValue
            total_profit_20 += df["p20"][i] * shares[i].varValue

    # total_profit = sum([p[i] * shares[i].varValue for i in range(n_companies)])
    # total_profit = total_profit_10 + total_profit_21
    allocations[ub] = shares_allocation
    print("Upper Bound on each allocation (number of shares): ", ub)
    print(f"Total Cost at T0: {total_cost_10:.2f}")
    print(f"Total Profit from T0 to T1: {total_profit_10:.2f}")
    # print()
    print(f"Total Cost at T1: {total_cost_21:.2f}")
    print(f"Total Profit from T1 to T2: {total_profit_21:.2f}")
    print(f"Total Profit from T0 to T2 (Overall): {total_profit_20:.2f}")
    print()

    if best_profit_10[0] is None or total_profit_10 > best_profit_10[1]:
        best_profit_10[0] = ub
        best_profit_10[1] = total_profit_10
    if best_profit_21[0] is None or total_profit_21 > best_profit_21[1]:
        best_profit_21[0] = ub
        best_profit_21[1] = total_profit_21
    if best_profit_20[0] is None or total_profit_20 > best_profit_20[1]:
        best_profit_20[0] = ub
        best_profit_20[1] = total_profit_20

print(f"Best Profit (T1 - T0): {best_profit_10}")
print(f"Best Profit (T2 - T1): {best_profit_21}")
print(f"Best Overall Profit (T2 - T0): {best_profit_20}")
# Out:
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  100
# Total Cost at T0: 999999.64
# Total Profit from T0 to T1: 181446.66
# Total Cost at T1: 1181446.30
# Total Profit from T1 to T2: 191201.75
# Total Profit from T0 to T2 (Overall): 372648.41
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  200
# Total Cost at T0: 999993.45
# Total Profit from T0 to T1: 172455.07
# Total Cost at T1: 1172448.52
# Total Profit from T1 to T2: 249477.79
# Total Profit from T0 to T2 (Overall): 421932.86
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  500
# Total Cost at T0: 999993.00
# Total Profit from T0 to T1: 212224.10
# Total Cost at T1: 1212217.10
# Total Profit from T1 to T2: 262077.25
# Total Profit from T0 to T2 (Overall): 474301.35
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  1000
# Total Cost at T0: 999989.10
# Total Profit from T0 to T1: 202570.14
# Total Cost at T1: 1202559.24
# Total Profit from T1 to T2: 342526.70
# Total Profit from T0 to T2 (Overall): 545096.84
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  2000
# Total Cost at T0: 999985.00
# Total Profit from T0 to T1: 183310.33
# Total Cost at T1: 1183295.33
# Total Profit from T1 to T2: 503371.02
# Total Profit from T0 to T2 (Overall): 686681.35
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  3000
# Total Cost at T0: 999999.60
# Total Profit from T0 to T1: 163542.52
# Total Cost at T1: 1163542.12
# Total Profit from T1 to T2: 664701.55
# Total Profit from T0 to T2 (Overall): 828244.07
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  4000
# Total Cost at T0: 999998.20
# Total Profit from T0 to T1: 144230.68
# Total Cost at T1: 1144228.88
# Total Profit from T1 to T2: 825606.44
# Total Profit from T0 to T2 (Overall): 969837.12
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  5000
# Total Cost at T0: 999994.10
# Total Profit from T0 to T1: 124970.87
# Total Cost at T1: 1124964.97
# Total Profit from T1 to T2: 986450.76
# Total Profit from T0 to T2 (Overall): 1111421.63
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  8000
# Total Cost at T0: 999993.65
# Total Profit from T0 to T1: 74514.93
# Total Cost at T1: 1074508.58
# Total Profit from T1 to T2: 1444421.52
# Total Profit from T0 to T2 (Overall): 1518936.45
#
# Optimal number of shares to buy for each company:
# Upper Bound on each allocation (number of shares):  10000
# Total Cost at T0: 999998.25
# Total Profit from T0 to T1: 69683.09
# Total Cost at T1: 1069681.34
# Total Profit from T1 to T2: 1655679.61
# Total Profit from T0 to T2 (Overall): 1725362.70
#
# Best Profit (T1 - T0): [500, 212224.1]
# Best Profit (T2 - T1): [10000, 1655679.6095430248]
# Best Overall Profit (T2 - T0): [10000, 1725362.6995430246]

# %%
df[(df["p20"] >= 0) & (df["p10"] <= 0)]
# Out:
#                  Name             join_key       t0       t1           t2  \
# 4    Aaron Industries           -1.0_AARON   263.20   258.78   295.829774
# 14       Alicon Cast.      531147.0_ALICON  1247.65  1243.92  1315.819900
# 15   Amba Enterprises      539196.0___NA__   238.00   235.05   283.694470
# 18       Ami Organics      543349.0_AMIORG  1303.45  1232.86  1328.871825
# 52     Brady & Morris      505690.0___NA__  1250.00  1213.32  1338.553685
# 56   Capacit'e Infra.    540710.0_CAPACITE   310.60   297.35   317.668028
# 59     Cera Sanitary.        532443.0_CERA  8655.35  8537.75  9379.765560
# 62   Colgate-Palmoliv      500830.0_COLPAL  2879.05  2872.05  3289.769952
# 65   Cyber Media Res.           -1.0_CMRSL   172.20   168.65   179.340553
# 67       D-Link India  533146.0_DLINKINDIA   485.10   462.63   540.591442
# 68      Dalmia Bharat   500097.0_DALMIASUG   414.45   392.55   446.450381
# 69       Danlaw Tech.      532329.0___NA__  1897.40  1787.46  1914.397900
# 70        DC Infotech         543636.0_DCI   235.00   225.62   245.612714
# 76      Delton Cables      504240.0___NA__   488.10   460.62   540.258357
# 85    Dynamatic Tech.  505242.0_DYNAMATECH  7377.70  6933.07  7470.617967
# 91    Endurance Tech.   540153.0_ENDURANCE  2702.00  2670.43  2848.009839
# 106  Gallantt Ispat L    532726.0_GALLANTT   361.00   349.18   387.609054
# 108     Garware Tech.   509557.0_GARFIBRES  4075.45  4069.76  4370.911494
# 118  Gujarat Fluoroch  542812.0_FLUOROCHEM  3227.10  3173.89  3398.141737
# 126   Himadri Special        500184.0_HSCL   395.00   382.46   404.555676
# 134  ICE Make Refrig.         -1.0_ICEMAKE   856.40   848.62   905.540861
# 154   Jyoti CNC Auto.    544081.0_JYOTICNC  1328.05  1326.16  1337.184045
# 160   Kalpataru Proj.        522287.0_KPIL  1151.30  1144.57  1191.635846
# 163    KCK Industries             -1.0_KCK   211.00   210.08   294.104917
# 164    Kingfa Science      524019.0_KINGFA  2135.10  2125.08  2279.645758
# 180    Logica Infoway      543746.0___NA__   254.75   247.16   255.749951
# 182  Lumax Auto Tech.   532796.0_LUMAXTECH   585.00   584.28   595.239929
# 197  Mayank Cattle Fo      544106.0___NA__   228.60   218.93   240.587481
# 211   Natl. Aluminium  532234.0_NATIONALUM   192.00   181.12   204.127581
# 221    Nitin Spinners   532698.0_NITINSPIN   362.20   352.67   365.045885
# 222   One Global Serv      514330.0___NA__   146.20   143.22   186.678140
# 230    Patels Airtemp      517417.0___NA__   729.60   708.08   740.751153
# 238       Pitti Engg.    513519.0_PITTIENG  1017.00  1010.42  1084.546867
# 239  POCL Enterprises      539195.0___NA__   432.95   418.26   460.589772
# 252  Prestige Estates    533274.0_PRESTIGE  1835.30  1731.51  1858.247587
# 265   Rajvi Logitrade      511185.0___NA__    11.29    10.63    50.200972
# 266   Ram Ratna Wires      522281.0_RAMRAT   391.30   378.35   406.367913
# 267   Ramdevbaba Sol.             -1.0_RBS    99.80    99.30   125.824920
# 268   Rane Brake Lin.         532987.0_RBL   991.60   921.87  1026.319568
# 269  Rashi Peripheral      544119.0_RPTECH   327.90   295.38   386.152755
# 271           Raymond     500330.0_RAYMOND  3046.20  2897.78  3148.609535
# 279        Roto Pumps        517500.0_ROTO   626.45   613.07   651.080019
# 296      Sharda Motor  535602.0_SHARDAMOTR  2305.90  2183.00  2367.264618
# 303  Simplex Castings      513472.0___NA__   195.00   194.54   207.681862
# 304   SJS Enterprises         543387.0_SJS   785.75   775.22   824.170929
# 315   Sportking India   539221.0_SPORTKING   865.15   828.54   912.481898
# 319       Sumuka Agro      532070.0___NA__   203.85   200.04   231.417703
# 347     Va Tech Wabag       533269.0_WABAG  1330.20  1293.77  1345.969269
# 354  Vishnu Prakash R       543974.0_VPRPL   199.85   199.11   228.196508
# 357         W H Brady      501391.0___NA__   636.00   598.79   637.951735
# 361  Yasho Industries       541167.0_YASHO  1978.70  1918.41  2031.446786
# 362       Yuken India       522108.0_YUKEN  1244.95  1225.84  1246.892044
#
#             p20         p21     p10  allocation
# 4     32.629774   37.049774   -4.42           0
# 14    68.169900   71.899900   -3.73           0
# 15    45.694470   48.644470   -2.95           0
# 18    25.421825   96.011825  -70.59           0
# 52    88.553685  125.233685  -36.68           0
# 56     7.068028   20.318028  -13.25           0
# 59   724.415560  842.015560 -117.60           0
# 62   410.719952  417.719952   -7.00           0
# 65     7.140553   10.690553   -3.55           0
# 67    55.491442   77.961442  -22.47           0
# 68    32.000381   53.900381  -21.90           0
# 69    16.997900  126.937900 -109.94           0
# 70    10.612714   19.992714   -9.38           0
# 76    52.158357   79.638357  -27.48           0
# 85    92.917967  537.547967 -444.63           0
# 91   146.009839  177.579839  -31.57           0
# 106   26.609054   38.429054  -11.82           0
# 108  295.461494  301.151494   -5.69           0
# 118  171.041737  224.251737  -53.21           0
# 126    9.555676   22.095676  -12.54           0
# 134   49.140861   56.920861   -7.78           0
# 154    9.134045   11.024045   -1.89           0
# 160   40.335846   47.065846   -6.73           0
# 163   83.104917   84.024917   -0.92           0
# 164  144.545758  154.565758  -10.02           0
# 180    0.999951    8.589951   -7.59           0
# 182   10.239929   10.959929   -0.72           0
# 197   11.987481   21.657481   -9.67           0
# 211   12.127581   23.007581  -10.88           0
# 221    2.845885   12.375885   -9.53           0
# 222   40.478140   43.458140   -2.98           0
# 230   11.151153   32.671153  -21.52           0
# 238   67.546867   74.126867   -6.58           0
# 239   27.639772   42.329772  -14.69           0
# 252   22.947587  126.737587 -103.79           0
# 265   38.910972   39.570972   -0.66       10000
# 266   15.067913   28.017913  -12.95           0
# 267   26.024920   26.524920   -0.50           0
# 268   34.719568  104.449568  -69.73           0
# 269   58.252755   90.772755  -32.52           0
# 271  102.409535  250.829535 -148.42           0
# 279   24.630019   38.010019  -13.38           0
# 296   61.364618  184.264618 -122.90           0
# 303   12.681862   13.141862   -0.46           0
# 304   38.420929   48.950929  -10.53           0
# 315   47.331898   83.941898  -36.61           0
# 319   27.567703   31.377703   -3.81           0
# 347   15.769269   52.199269  -36.43           0
# 354   28.346508   29.086508   -0.74           0
# 357    1.951735   39.161735  -37.21           0
# 361   52.746786  113.036786  -60.29           0
# 362    1.942044   21.052044  -19.11           0

# %%
df["allocation"] = allocations[10000]
df.head()
# Out:
#                Name            join_key        t0        t1            t2  \
# 0        20 Microns  533022.0_20MICRONS    225.45    229.42    227.561919
# 1          3M India    523395.0_3MINDIA  37310.00  41655.06  45885.999153
# 2             A B B        500002.0_ABB   8531.25   9620.43  10533.824027
# 3    Aakash Explor.         -1.0_AAKASH     14.16     13.30    -58.956361
# 4  Aaron Industries          -1.0_AARON    263.20    258.78    295.829774
#
#            p20          p21      p10  allocation
# 0     2.111919    -1.858081     3.97           0
# 1  8575.999153  4230.939153  4345.06           0
# 2  2002.574027   913.394027  1089.18           0
# 3   -73.116361   -72.256361    -0.86           0
# 4    32.629774    37.049774    -4.42           0

# %%
sum(df["allocation"] > 0)
# Out:
# 3

# %%
df.to_csv("ATTEMPT 5.csv", index = False)

# %% [markdown]
# # Attempt 6
# ### Reducing risks with a small upper bound on per stock allocation to 1000

# %%
df["allocation"] = allocations[1000]
df.head()
# Out:
#                Name            join_key        t0        t1            t2  \
# 0        20 Microns  533022.0_20MICRONS    225.45    229.42    227.561919
# 1          3M India    523395.0_3MINDIA  37310.00  41655.06  45885.999153
# 2             A B B        500002.0_ABB   8531.25   9620.43  10533.824027
# 3    Aakash Explor.         -1.0_AAKASH     14.16     13.30    -58.956361
# 4  Aaron Industries          -1.0_AARON    263.20    258.78    295.829774
#
#            p20          p21      p10  allocation
# 0     2.111919    -1.858081     3.97           0
# 1  8575.999153  4230.939153  4345.06           0
# 2  2002.574027   913.394027  1089.18           0
# 3   -73.116361   -72.256361    -0.86           0
# 4    32.629774    37.049774    -4.42           0

# %%
sum(df["allocation"] > 0)
# Out:
# 6

# %%
df.to_csv("ATTEMPT 6.csv", index = False)
